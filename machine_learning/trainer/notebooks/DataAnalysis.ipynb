# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#       5 import joblib
#       6
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
df = pd.read_csv("../data/mock_data.csv")
df.describe()
# Out:
#        temperature           CO2        Light       Water  Minutes_Slept  \
# count    100.000000   100.000000   100.000000  100.000000     100.000000
# mean      19.680000  1181.860000  1493.660000    1.950000     455.090000
# std        1.118079   286.247333   189.201844    1.539874      59.360582
# min       18.000000   476.000000   932.000000    0.000000     298.000000
# 25%       19.000000   954.000000  1367.750000    1.000000     417.500000
# 50%       20.000000  1177.500000  1493.500000    2.000000     459.000000
# 75%       20.000000  1378.000000  1616.000000    3.000000     494.750000
# max       22.000000  1920.000000  1927.000000    6.000000     593.000000
#
#        Minutes_Awake  current ELO  opponent ELO    user_won
# count     100.000000   100.000000    100.000000  100.000000
# mean      451.330000  2291.540000   2251.210000    0.410000
# std        56.960212   194.164016    193.533506    0.494311
# min       280.000000  1792.000000   1860.000000    0.000000
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 4))
plt.bar(['Lost (0)', 'Won (1)'], [sum(df['user_won'] == 0), sum(df['user_won'] == 1)], color=['salmon', 'steelblue'])
plt.title('Distribution of Target Variable (user_won)')
plt.ylabel('Count')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 import matplotlib.pyplot as plt
#       2
#       3 plt.figure(figsize=(6, 4))
# ----> 4 plt.bar(['Lost (0)', 'Won (1)'], [sum(df['user_won'] == 0), sum(df['user_won'] == 1)], color=['salmon', 'steelblue'])
#       5 plt.title('Distribution of Target Variable (user_won)')
#       6 plt.ylabel('Count')
#       7 plt.tight_layout()
#
# NameError: name 'df' is not defined

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 5, figsize=(18, 4))

columns = ['minutes_slept', 'minutes_awake', 'env_score', 'light', 'target']

for ax, col in zip(axes, columns):
    if col == 'target':
        ax.bar(['Lost (0)', 'Won (1)'], df[col].value_counts().sort_index(), color=['salmon', 'steelblue'])
    else:
        ax.hist(df[col], bins=30, color='steelblue', edgecolor='white')
    ax.set_title(col)
    ax.set_ylabel('Count')

plt.suptitle('Feature Distributions', fontsize=14, y=1.02)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\mikol\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'minutes_slept'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 11
# ...
